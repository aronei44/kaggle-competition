# %%
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler, OneHotEncoder, RobustScaler
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# %%
df = pd.read_csv("../data/train.csv", index_col=['Id'])
df.head()
# Out:
#                     AB          AF          AH         AM        AR        AX  \
# Id
# 000ff2bfdfe9  0.209377  3109.03329   85.200147  22.394407  8.138688  0.699861
# 007255e47698  0.145282   978.76416   85.200147  36.968889  8.138688  3.632190
# 013f2bd269f5  0.470030  2635.10654   85.200147  32.360553  8.138688  6.732840
# 043ac50845d5  0.252107  3819.65177  120.201618  77.112203  8.138688  3.685344
# 044fb8a146ec  0.380297  3733.04844   85.200147  14.103738  8.138688  3.942255
#
#                     AY         AZ          BC         BD   ...        FL  \
# Id                                                         ...
# 000ff2bfdfe9  0.025578   9.812214    5.555634  4126.58731  ...  7.298162
# 007255e47698  0.025578  13.517790    1.229900  5496.92824  ...  0.173229
# 013f2bd269f5  0.025578  12.824570    1.229900  5135.78024  ...  7.709560
# 043ac50845d5  0.025578  11.053708    1.229900  4169.67738  ...  6.122162
# 044fb8a146ec  0.054810   3.396778  102.151980  5728.73412  ...  8.153058
#
#                     FR        FS         GB          GE            GF  \
# Id
# 000ff2bfdfe9   1.73855  0.094822  11.339138   72.611063   2003.810319
# 007255e47698   0.49706  0.568932   9.292698   72.611063  27981.562750
# 013f2bd269f5   0.97556  1.198821  37.077772   88.609437  13676.957810
# 043ac50845d5   0.49706  0.284466  18.529584   82.416803   2094.262452
# 044fb8a146ec  48.50134  0.121914  16.408728  146.109943   8524.370502
#
#                      GH         GI         GL  Class
# Id
# 000ff2bfdfe9  22.136229  69.834944   0.120343      1
# 007255e47698  29.135430  32.131996  21.978000      0
# 013f2bd269f5  28.022851  35.192676   0.196941      0
# 043ac50845d5  39.948656  90.493248   0.155829      0
# 044fb8a146ec  45.381316  36.262628   0.096614      1
#
# [5 rows x 57 columns]

# %%
X = df.drop(columns=['Class'], axis=1)
y = df.Class

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=42, stratify=y)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((493, 56), (124, 56), (493,), (124,))

# %%
categorical_pipeline = Pipeline([
    ("inputer", SimpleImputer(strategy="most_frequent")),
    ("onehot", OneHotEncoder(handle_unknown = 'ignore'))
])
numerical_pipeline = Pipeline([
    ("inputer", SimpleImputer(strategy="mean")),
    ("scaler", RobustScaler())
])
preprocessor = ColumnTransformer([
    ("categoric", categorical_pipeline, ['EJ']),
    ("numeric", numerical_pipeline, ['AB', 'AF', 'AH', 'AM', 'AR', 'AX', 'AY', 'AZ', 'BC', 'BD ', 'BN', 'BP',
       'BQ', 'BR', 'BZ', 'CB', 'CC', 'CD ', 'CF', 'CH', 'CL', 'CR', 'CS', 'CU',
       'CW ', 'DA', 'DE', 'DF', 'DH', 'DI', 'DL', 'DN', 'DU', 'DV', 'DY', 'EB',
       'EE', 'EG', 'EH', 'EL', 'EP', 'EU', 'FC', 'FD ', 'FE', 'FI', 'FL',
       'FR', 'FS', 'GB', 'GE', 'GF', 'GH', 'GI', 'GL']),
])
pipeline = Pipeline([
    ("prep", preprocessor),
    ("algo", KNeighborsClassifier())
])

# %%
parameter = {
    "algo__n_neighbors": range(1, 51, 2),
    "algo__weights": ['uniform','distance'],
    "algo__p": range(1,10)
}
model = GridSearchCV(pipeline, parameter, cv=3, n_jobs=-1, verbose=1, scoring='f1')
model.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 450 candidates, totalling 1350 fits
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('prep',
#                                         ColumnTransformer(transformers=[('categoric',
#                                                                          Pipeline(steps=[('inputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('onehot',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['EJ']),
#                                                                         ('numeric',
#                                                                          Pipeline(steps=[('inputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('scaler',
#                                                                                           RobustScaler())]),
#                                                                          ['AB',
#                                                                           'AF',
#                                                                           'AH',
#                                                                           'AM',
#                                                                           'AR',
#                                                                           'AX',
#                                                                           'AY',
#                                                                           'AZ',
#                                                                           'BC',
#                                                                           'BD ',
#                                                                           'BN',
#                                                                           'BP',
#                                                                           'BQ',
#                                                                           'BR',
#                                                                           'BZ',
#                                                                           'CB',
#                                                                           'CC',
#                                                                           'CD ',
#                                                                           'CF',
#                                                                           'CH',
#                                                                           'CL',
#                                                                           'CR',
#                                                                           'CS',
#                                                                           'CU',
#                                                                           'CW ',
#                                                                           'DA',
#                                                                           'DE',
#                                                                           'DF',
#                                                                           'DH',
#                                                                           'DI', ...])])),
#                                        ('algo', KNeighborsClassifier())]),
#              n_jobs=-1,
#              param_grid={'algo__n_neighbors': range(1, 51, 2),
#                          'algo__p': range(1, 10),
#                          'algo__weights': ['uniform', 'distance']},
#              scoring='f1', verbose=1)

# %%
model.score(X_train, y_train), model.best_score_, model.score(X_test, y_test), model.best_params_
# Out:
# (1.0,
#  0.607912457912458,
#  0.5405405405405405,
#  {'algo__n_neighbors': 1, 'algo__p': 1, 'algo__weights': 'uniform'})

# %%
from sklearn.svm import SVC

# %%
pipeline = Pipeline([
    ("prep", preprocessor),
    ("algo", SVC())
])
parameter = {
    'algo__C' : range(1,20),
    'algo__gamma' : ('auto','scale'),
    'algo__tol': [.1,.01,.001,.0001]
}
model = GridSearchCV(pipeline, parameter, cv=3, n_jobs=-1, verbose=1, scoring='f1')
model.fit(X_train, y_train)
model.score(X_train, y_train), model.best_score_, model.score(X_test, y_test), model.best_params_
# Out:
# Fitting 3 folds for each of 152 candidates, totalling 456 fits
# (0.925925925925926,
#  0.5800075585789871,
#  0.6486486486486486,
#  {'algo__C': 3, 'algo__gamma': 'scale', 'algo__tol': 0.1})

# %%
from sklearn.linear_model import LogisticRegression

# %%
pipeline = Pipeline([
    ("prep", preprocessor),
    ("algo", LogisticRegression())
])
parameter = {
    'algo__C' : range(1,20),
    'algo__verbose' : range(1,10),
    'algo__tol': [.1,.01,.001,.0001]
}
model = RandomizedSearchCV(pipeline, parameter, cv=3, n_jobs=-1, verbose=1, scoring='f1')
model.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# RandomizedSearchCV(cv=3,
#                    estimator=Pipeline(steps=[('prep',
#                                               ColumnTransformer(transformers=[('categoric',
#                                                                                Pipeline(steps=[('inputer',
#                                                                                                 SimpleImputer(strategy='most_frequent')),
#                                                                                                ('onehot',
#                                                                                                 OneHotEncoder(handle_unknown='ignore'))]),
#                                                                                ['EJ']),
#                                                                               ('numeric',
#                                                                                Pipeline(steps=[('inputer',
#                                                                                                 SimpleImputer()),
#                                                                                                ('scaler',
#                                                                                                 StandardScaler())]),
#                                                                                ['AB',
#                                                                                 'AF',
#                                                                                 'AH',
#                                                                                 'AM',
#                                                                                 'AR',
#                                                                                 'AX',
#                                                                                 'AY',
#                                                                                 'AZ',
#                                                                                 'BC',
#                                                                                 'BD ',
#                                                                                 'BN',
#                                                                                 'BP',
#                                                                                 'BQ',
#                                                                                 'BR',
#                                                                                 'BZ',
#                                                                                 'CB',
#                                                                                 'CC',
#                                                                                 'CD ',
#                                                                                 'CF',
#                                                                                 'CH',
#                                                                                 'CL',
#                                                                                 'CR',
#                                                                                 'CS',
#                                                                                 'CU',
#                                                                                 'CW ',
#                                                                                 'DA',
#                                                                                 'DE',
#                                                                                 'DF',
#                                                                                 'DH',
#                                                                                 'DI', ...])])),
#                                              ('algo', LogisticRegression())]),
#                    n_jobs=-1,
#                    param_distributions={'algo__C': range(1, 20),
#                                         'algo__tol': [0.1, 0.01, 0.001, 0.0001],
#                                         'algo__verbose': range(1, 10)},
#                    scoring='f1', verbose=1)

# %%
model.score(X_train, y_train), model.best_score_, model.score(X_test, y_test), model.best_params_
# Out:
# (0.7875,
#  0.6217948717948718,
#  0.7441860465116279,
#  {'algo__verbose': 2, 'algo__tol': 0.0001, 'algo__C': 1})

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
pipeline = Pipeline([
    ("prep", preprocessor),
    ("algo", RandomForestClassifier())
])

# %%
pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('categoric',
#                                     Pipeline(steps=[('inputer',
#                                                      SimpleImputer(strategy='most_frequent')),
#                                                     ('onehot',
#                                                      OneHotEncoder(handle_unknown='ignore'))]),
#                                     ['EJ']),
#                                    ('numeric',
#                                     Pipeline(steps=[('inputer', SimpleImputer()),
#                                                     ('scaler', StandardScaler())]),
#                                     ['AB', 'AF', 'AH', 'AM', 'AR', 'AX', 'AY',
#                                      'AZ', 'BC', 'BD ', 'BN', 'BP', 'BQ', 'BR',
#                                      'BZ', 'CB', 'CC', 'CD ', 'CF', 'CH', 'CL',
#                                      'CR', 'CS', 'CU', 'CW ', 'DA', 'DE', 'DF',
#                                      'DH', 'DI', ...])])),
#   ('algo', RandomForestClassifier())],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('categoric',
#                                   Pipeline(steps=[('inputer',
#                                                    SimpleImputer(strategy='most_frequent')),
#                                                   ('onehot',
#                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                   ['EJ']),
#                                  ('numeric',
#                                   Pipeline(steps=[('inputer', SimpleImputer()),
#                                                   ('scaler', StandardScaler())]),
#                                   ['AB', 'AF', 'AH', 'AM', 'AR', 'AX', 'AY',
#                                    'AZ', 'BC', 'BD ', 'BN', 'BP', 'BQ', 'BR',
#                                    'BZ', 'CB', 'CC', 'CD ', 'CF', 'CH', 'CL',
#                                    'CR', 'CS', 'CU', 'CW ', 'DA', 'DE', 'DF',
#                                    'DH', 'DI', ...])]),
#  'algo': RandomForestClassifier(),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('categoric',
#    Pipeline(steps=[('inputer', SimpleImputer(strategy='most_frequent')),
#                    ('onehot', OneHotEncoder(handle_unknown='ignore'))]),
#    ['EJ']),
#   ('numeric',
#    Pipeline(steps=[('inputer', SimpleImputer()), ('scaler', StandardScaler())]),
#    ['AB',
#     'AF',
#     'AH',
#     'AM',
#     'AR',
#     'AX',
#     'AY',
#     'AZ',
#     'BC',
#     'BD ',
#     'BN',
#     'BP',
#     'BQ',
#     'BR',
#     'BZ',
#     'CB',
#     'CC',
#     'CD ',
#     'CF',
#     'CH',
#     'CL',
#     'CR',
#     'CS',
#     'CU',
#     'CW ',
#     'DA',
#     'DE',
#     'DF',
#     'DH',
#     'DI',
#     'DL',
#     'DN',
#     'DU',
#     'DV',
#     'DY',
#     'EB',
#     'EE',
#     'EG',
#     'EH',
#     'EL',
#     'EP',
#     'EU',
#     'FC',
#     'FD ',
#     'FE',
#     'FI',
#     'FL',
#     'FR',
#     'FS',
#     'GB',
#     'GE',
#     'GF',
#     'GH',
#     'GI',
#     'GL'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__categoric': Pipeline(steps=[('inputer', SimpleImputer(strategy='most_frequent')),
#                  ('onehot', OneHotEncoder(handle_unknown='ignore'))]),
#  'prep__numeric': Pipeline(steps=[('inputer', SimpleImputer()), ('scaler', StandardScaler())]),
#  'prep__categoric__memory': None,
#  'prep__categoric__steps': [('inputer',
#    SimpleImputer(strategy='most_frequent')),
#   ('onehot', OneHotEncoder(handle_unknown='ignore'))],
#  'prep__categoric__verbose': False,
#  'prep__categoric__inputer': SimpleImputer(strategy='most_frequent'),
#  'prep__categoric__onehot': OneHotEncoder(handle_unknown='ignore'),
#  'prep__categoric__inputer__add_indicator': False,
#  'prep__categoric__inputer__copy': True,
#  'prep__categoric__inputer__fill_value': None,
#  'prep__categoric__inputer__keep_empty_features': False,
#  'prep__categoric__inputer__missing_values': nan,
#  'prep__categoric__inputer__strategy': 'most_frequent',
#  'prep__categoric__onehot__categories': 'auto',
#  'prep__categoric__onehot__drop': None,
#  'prep__categoric__onehot__dtype': numpy.float64,
#  'prep__categoric__onehot__feature_name_combiner': 'concat',
#  'prep__categoric__onehot__handle_unknown': 'ignore',
#  'prep__categoric__onehot__max_categories': None,
#  'prep__categoric__onehot__min_frequency': None,
#  'prep__categoric__onehot__sparse': 'deprecated',
#  'prep__categoric__onehot__sparse_output': True,
#  'prep__numeric__memory': None,
#  'prep__numeric__steps': [('inputer', SimpleImputer()),
#   ('scaler', StandardScaler())],
#  'prep__numeric__verbose': False,
#  'prep__numeric__inputer': SimpleImputer(),
#  'prep__numeric__scaler': StandardScaler(),
#  'prep__numeric__inputer__add_indicator': False,
#  'prep__numeric__inputer__copy': True,
#  'prep__numeric__inputer__fill_value': None,
#  'prep__numeric__inputer__keep_empty_features': False,
#  'prep__numeric__inputer__missing_values': nan,
#  'prep__numeric__inputer__strategy': 'mean',
#  'prep__numeric__scaler__copy': True,
#  'prep__numeric__scaler__with_mean': True,
#  'prep__numeric__scaler__with_std': True,
#  'algo__bootstrap': True,
#  'algo__ccp_alpha': 0.0,
#  'algo__class_weight': None,
#  'algo__criterion': 'gini',
#  'algo__max_depth': None,
#  'algo__max_features': 'sqrt',
#  'algo__max_leaf_nodes': None,
#  'algo__max_samples': None,
#  'algo__min_impurity_decrease': 0.0,
#  'algo__min_samples_leaf': 1,
#  'algo__min_samples_split': 2,
#  'algo__min_weight_fraction_leaf': 0.0,
#  'algo__n_estimators': 100,
#  'algo__n_jobs': None,
#  'algo__oob_score': False,
#  'algo__random_state': None,
#  'algo__verbose': 0,
#  'algo__warm_start': False}

# %%
parameter = {
    # 'algo__min_samples_leaf' : range(1,10),
    # 'algo__max_depth' : range(1,10),
    # 'algo__max_samples' : range(1,10),
}
model = RandomizedSearchCV(pipeline, parameter, cv=3, n_jobs=-1, verbose=1, scoring='f1', n_iter=20)
model.fit(X_train, y_train)
model.score(X_train, y_train), model.best_score_, model.score(X_test, y_test), model.best_params_
# Out:
# c:\project\kompetisi-kaggle\venv\lib\site-packages\sklearn\model_selection\_search.py:307: UserWarning: The total space of parameters 1 is smaller than n_iter=20. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# (1.0, 0.6743443754313319, 0.7499999999999999, {})

# %%
from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, ExtraTreesClassifier, GradientBoostingClassifier

# %%
pipeline = Pipeline([
    ("prep", preprocessor),
    ("algo", GradientBoostingClassifier())
])

# %%
pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('prep',
#    ColumnTransformer(transformers=[('categoric',
#                                     Pipeline(steps=[('inputer',
#                                                      SimpleImputer(strategy='most_frequent')),
#                                                     ('onehot',
#                                                      OneHotEncoder(handle_unknown='ignore'))]),
#                                     ['EJ']),
#                                    ('numeric',
#                                     Pipeline(steps=[('inputer', SimpleImputer()),
#                                                     ('scaler', StandardScaler())]),
#                                     ['AB', 'AF', 'AH', 'AM', 'AR', 'AX', 'AY',
#                                      'AZ', 'BC', 'BD ', 'BN', 'BP', 'BQ', 'BR',
#                                      'BZ', 'CB', 'CC', 'CD ', 'CF', 'CH', 'CL',
#                                      'CR', 'CS', 'CU', 'CW ', 'DA', 'DE', 'DF',
#                                      'DH', 'DI', ...])])),
#   ('algo', GradientBoostingClassifier())],
#  'verbose': False,
#  'prep': ColumnTransformer(transformers=[('categoric',
#                                   Pipeline(steps=[('inputer',
#                                                    SimpleImputer(strategy='most_frequent')),
#                                                   ('onehot',
#                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                   ['EJ']),
#                                  ('numeric',
#                                   Pipeline(steps=[('inputer', SimpleImputer()),
#                                                   ('scaler', StandardScaler())]),
#                                   ['AB', 'AF', 'AH', 'AM', 'AR', 'AX', 'AY',
#                                    'AZ', 'BC', 'BD ', 'BN', 'BP', 'BQ', 'BR',
#                                    'BZ', 'CB', 'CC', 'CD ', 'CF', 'CH', 'CL',
#                                    'CR', 'CS', 'CU', 'CW ', 'DA', 'DE', 'DF',
#                                    'DH', 'DI', ...])]),
#  'algo': GradientBoostingClassifier(),
#  'prep__n_jobs': None,
#  'prep__remainder': 'drop',
#  'prep__sparse_threshold': 0.3,
#  'prep__transformer_weights': None,
#  'prep__transformers': [('categoric',
#    Pipeline(steps=[('inputer', SimpleImputer(strategy='most_frequent')),
#                    ('onehot', OneHotEncoder(handle_unknown='ignore'))]),
#    ['EJ']),
#   ('numeric',
#    Pipeline(steps=[('inputer', SimpleImputer()), ('scaler', StandardScaler())]),
#    ['AB',
#     'AF',
#     'AH',
#     'AM',
#     'AR',
#     'AX',
#     'AY',
#     'AZ',
#     'BC',
#     'BD ',
#     'BN',
#     'BP',
#     'BQ',
#     'BR',
#     'BZ',
#     'CB',
#     'CC',
#     'CD ',
#     'CF',
#     'CH',
#     'CL',
#     'CR',
#     'CS',
#     'CU',
#     'CW ',
#     'DA',
#     'DE',
#     'DF',
#     'DH',
#     'DI',
#     'DL',
#     'DN',
#     'DU',
#     'DV',
#     'DY',
#     'EB',
#     'EE',
#     'EG',
#     'EH',
#     'EL',
#     'EP',
#     'EU',
#     'FC',
#     'FD ',
#     'FE',
#     'FI',
#     'FL',
#     'FR',
#     'FS',
#     'GB',
#     'GE',
#     'GF',
#     'GH',
#     'GI',
#     'GL'])],
#  'prep__verbose': False,
#  'prep__verbose_feature_names_out': True,
#  'prep__categoric': Pipeline(steps=[('inputer', SimpleImputer(strategy='most_frequent')),
#                  ('onehot', OneHotEncoder(handle_unknown='ignore'))]),
#  'prep__numeric': Pipeline(steps=[('inputer', SimpleImputer()), ('scaler', StandardScaler())]),
#  'prep__categoric__memory': None,
#  'prep__categoric__steps': [('inputer',
#    SimpleImputer(strategy='most_frequent')),
#   ('onehot', OneHotEncoder(handle_unknown='ignore'))],
#  'prep__categoric__verbose': False,
#  'prep__categoric__inputer': SimpleImputer(strategy='most_frequent'),
#  'prep__categoric__onehot': OneHotEncoder(handle_unknown='ignore'),
#  'prep__categoric__inputer__add_indicator': False,
#  'prep__categoric__inputer__copy': True,
#  'prep__categoric__inputer__fill_value': None,
#  'prep__categoric__inputer__keep_empty_features': False,
#  'prep__categoric__inputer__missing_values': nan,
#  'prep__categoric__inputer__strategy': 'most_frequent',
#  'prep__categoric__onehot__categories': 'auto',
#  'prep__categoric__onehot__drop': None,
#  'prep__categoric__onehot__dtype': numpy.float64,
#  'prep__categoric__onehot__feature_name_combiner': 'concat',
#  'prep__categoric__onehot__handle_unknown': 'ignore',
#  'prep__categoric__onehot__max_categories': None,
#  'prep__categoric__onehot__min_frequency': None,
#  'prep__categoric__onehot__sparse': 'deprecated',
#  'prep__categoric__onehot__sparse_output': True,
#  'prep__numeric__memory': None,
#  'prep__numeric__steps': [('inputer', SimpleImputer()),
#   ('scaler', StandardScaler())],
#  'prep__numeric__verbose': False,
#  'prep__numeric__inputer': SimpleImputer(),
#  'prep__numeric__scaler': StandardScaler(),
#  'prep__numeric__inputer__add_indicator': False,
#  'prep__numeric__inputer__copy': True,
#  'prep__numeric__inputer__fill_value': None,
#  'prep__numeric__inputer__keep_empty_features': False,
#  'prep__numeric__inputer__missing_values': nan,
#  'prep__numeric__inputer__strategy': 'mean',
#  'prep__numeric__scaler__copy': True,
#  'prep__numeric__scaler__with_mean': True,
#  'prep__numeric__scaler__with_std': True,
#  'algo__ccp_alpha': 0.0,
#  'algo__criterion': 'friedman_mse',
#  'algo__init': None,
#  'algo__learning_rate': 0.1,
#  'algo__loss': 'log_loss',
#  'algo__max_depth': 3,
#  'algo__max_features': None,
#  'algo__max_leaf_nodes': None,
#  'algo__min_impurity_decrease': 0.0,
#  'algo__min_samples_leaf': 1,
#  'algo__min_samples_split': 2,
#  'algo__min_weight_fraction_leaf': 0.0,
#  'algo__n_estimators': 100,
#  'algo__n_iter_no_change': None,
#  'algo__random_state': None,
#  'algo__subsample': 1.0,
#  'algo__tol': 0.0001,
#  'algo__validation_fraction': 0.1,
#  'algo__verbose': 0,
#  'algo__warm_start': False}

# %%
parameter = {
    'algo__learning_rate': [.1,.01,.001,.0001],
    'algo__tol': [.1,.01,.001,.0001],
    'algo__max_features': range(1,10),
    'algo__max_depth': range(1,10)
}
model = GridSearchCV(pipeline, parameter, cv=3, n_jobs=-1, verbose=1, scoring='f1')
model.fit(X_train, y_train)
model.score(X_train, y_train), model.best_score_, model.score(X_test, y_test), model.best_params_
# Out:
# Fitting 3 folds for each of 1296 candidates, totalling 3888 fits
# (1.0,
#  0.7745098039215687,
#  0.7692307692307693,
#  {'algo__learning_rate': 0.1,
#   'algo__max_depth': 5,
#   'algo__max_features': 8,
#   'algo__tol': 0.01})
